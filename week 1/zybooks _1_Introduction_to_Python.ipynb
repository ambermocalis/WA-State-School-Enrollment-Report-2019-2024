# %% [markdown]
# # 1. Introduction to Python

# %% [markdown]
# ### 1.1 Programming (general)

# %% [markdown]
# A computer program consists of instructions executing one at a time. Basic instruction types are:
#
#     Input: A program receives data from a file, keyboard, touchscreen, network, etc.
#     Process: A program performs computations on that data, such as adding two values like x + y.
#     Output: A program puts that data somewhere, such as a file, screen, or network.

# %%
x = 2 # input assigning x as value 2
y = 5 # inpute assigning y as value 5

z = x + y # process z as sum of x and y
print("z is",z) # output z

# %% [markdown]
# ### 1.2 Programming using Python

# %% [markdown]
# The Python interpreter - computer program that executes code written in the Python programming language.
# An interactive interpreter - allows the user to execute one line of code at a time.

# %% [markdown]
# ### 1.3 Basic input and output

# %% [markdown]
# The primary way to print output is to use the built-in function print(). Ex: print('hello world').

# %%
print('hello world')

# %% [markdown]
# Newline characters
#
# newline character - output can be moved to the next line by printing "\n"
#
# Ex: print('1\n2\n3') prints "1" on the first line, "2" on the second line, and "3" on the third line of output. "\n" consists of two characters, \ and n, but together are considered by the Python interpreter as a single character.

# %% [markdown]
# ##### Figure 1.3.5: Printing using newline characters.

# %%
#example 
Ex: print('1\n2\n3')

# %% [markdown]
# ##### Figure 1.3.6: Printing without text.

# %%
# newlines using multiple print statements.
print('123')
print()
print('abc')
#notice it prints a blank line.

# %% [markdown]
# ##### Figure 1.3.9: Basic input example.

# %%
# use input() to prompt user inputs.
hours = 40
weeks = 52

#note the "input" command prompts a user input. 
hourly_wage = int(input('Enter hourly wage: '))

print('Salary is', hourly_wage * hours * weeks)

# %% [markdown]
# ### 1.4 Errors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Syntax Error - violates a programming language's rules

# %%
user_num = 55
new_sal = 100

print(new_sal) print(user_num) #not allowed to have two print statemetns in the same line


# note that with VS Code, the specific error and location are given.

# %% [markdown]
# ### Indentation Error - incorrect indentation

# %%
#IndentationError
def check_number(a):
if a > 2:### Indentation Error - incorrect indentationz
if a < 7:
return "Number is between 2 and 7"

# %% [markdown]
# ### Value Error - wrong value input into program

# %%
int("number")

# %% [markdown]
# ### Name Error - Calling a variable that does not exist

# %%
print(name)

# %% [markdown]
# ### Type Error - using the wong type of data

# %%
#TypeError
geek = "Geeks"
num = 4
print(geek + num + geek)

# %% [markdown]
# ### Logic Error - a program loads correctly but would not behave as intended (often called a bug)

# %%
current_salary = 100

raise_percentage = 5  # Logic error gives a 500% raise instead of 5%.
new_salary = current_salary + (current_salary * raise_percentage)
print('New salary:', new_salary)

# %% [markdown]
# ##### 1.10 Python example: Salary calculation
#
# zyDE 1.10.1: Executing Python code using the interpreter.
# The following program calculates yearly and monthly salary given an hourly wage. The program assumes 40 work hours per week and 50 work weeks per year.
#
# Insert the correct number in the code below to print a monthly salary. Then run the program. The monthly salary should be 3333.333...

# %%
hourly_wage = 20

print('Annual salary is: ')
print(hourly_wage * 40 * 50)
print()

print('Monthly salary is: ')
print(((hourly_wage * 40 * 50) / 1))
print()

# FIXME: The above is wrong. Change 
#        the 1 so that the statement
#        outputs monthly salary.

# %%
my_str = 'Agt2t3afc2kjMhagrds!'
print(my_str[::2])
# Out:
# AttackMars

# %%
color = 'pearl'
my_slice = color[0:-3]
print(my_slice)
# Out:
# pe

# %%
full_lyric = input()

sliced_string = full_lyric[1:-1]

print(sliced_string)
# Out:
#  amazing grace how sweet the sound
# mazing grace how sweet the soun

# %%
full_saying = input()

partial_saying = full_saying[:len(full_saying)//2:4]

print(partial_saying)
# Out:
#  row row row your boat
# rrr

# %%
	def calc_circle_area(circle_diameter):
	    pi_val = 3.14159265
	   
	    circle_radius = circle_diameter / 2.0
	    circle_area = pi_val * circle_radius * circle_radius
	    return circle_area
	
	def calc_pizza_calories(pizza_diameter):
	    calories_per_square_inch = 16.7    # Regular crust pepperoni pizza
	   
	    total_calories = calc_circle_area(pizza_diameter) * calories_per_square_inch
	    return total_calories

	
	print(f'12 inch pizza has {calc_pizza_calories(12.0):.2f} calories.')
	print(f'14 inch pizza has {calc_pizza_calories(14.0):.2f} calories.')
# Out:
# 12 inch pizza has 1888.73 calories.
# 14 inch pizza has 2570.77 calories.

# %%
def get_minutes_as_hours(orig_minutes):
    return orig_minutes/60

minutes = float(input())
print(get_minutes_as_hours(minutes))
# Out:
#  423
# 7.05

# %%
def change_values(x, y):
    result = x + y
    return result

print(change_values(2, 1))
# Out:
# 3

# %%
print(5*'100')
# Out:
# 100100100100100

# %%
import math

# %%
print(f'{13.69//30:.3f}')
# Out:
# 0.000

# %%
print('Initial global namespace: ')
print(globals())

my_var = "This is a variable"
print('\nCreated new variable')
print(globals())

def my_func():
    pass

print('\nCreated new function')
print(globals())
# Out:
# Initial global namespace:
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
# ...

# %%
builtin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 builtin()
#
# NameError: name 'builtin' is not defined

# %%
built_in()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 built_in()
#
# NameError: name 'built_in' is not defined

# %%
global()
# Out:
#   Cell In[48], line 1
#     global()
#           ^
# SyntaxError: invalid syntax

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
# ...

# %%
def birthday(age):
   '''Celebrate birthday!'''
   age = age + 1

timmy_age = 7

birthday(timmy_age)
print(f'Timmy is {timmy_age}')
# Out:
# Timmy is 7

# %%
def birthday(age):
   '''Celebrate birthday!'''
   age = age + 1
   return age
   

timmy_age = 7


print(f'Timmy is {birthday(timmy_age)}')
# Out:
# Timmy is 8
